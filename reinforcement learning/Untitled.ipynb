# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import (
    notebook_login,
)  # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
# Out:
# Matplotlib created a temporary cache directory at /var/folders/3d/3y5f1kzj0dbf0ltx0lwh2l600000gn/T/matplotlib-_taafh1e because the default path (/Users/paytonison/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
    # Take a random action
    action = env.action_space.sample()
    print("Action taken:", action)

    # Do this action in the environment and get
    # next_state, reward, terminated, truncated and info
    observation, reward, terminated, truncated, info = env.step(action)

    # If the game is terminated (in our case we land, crashed) or truncated (timeout)
    if terminated or truncated:
        # Reset the environment
        print("Environment is reset")
        observation, info = env.reset()

env.close()
# Out:
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 2
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 0
# Action taken: 0
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 1
# Action taken: 1

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())  # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [ 1.0697136   0.19674467 -4.3750734  -0.7776237  -0.13223352  1.9777201
#   0.9100175   0.68257374]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())  # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
# Create the environment
env = make_vec_env("LunarLander-v2", n_envs=16)

# %%
# Create environment
env = gym.make('LunarLander-v2')

# Instantiate the agent
model = PPO('MlpPolicy', env, verbose=1)
# Train the agent
model.learn(total_timesteps=int(2e5))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.4     |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    fps             | 5597     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94           |
# |    ep_rew_mean          | -173         |
# | time/                   |              |
# |    fps                  | 3843         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0068150335 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00606     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 696          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 1.6e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.8        |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 3492        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008880303 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0864     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 579         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 1.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.3        |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 3396        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007395718 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00425    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 258         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 552         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.7        |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 3330        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010216923 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00204    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00759    |
# |    value_loss           | 428         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 3300        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010245448 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000724   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 156         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0089     |
# |    value_loss           | 352         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 3271         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0121185025 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.000333    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 279          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 3210        |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010161894 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.226      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 191         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 300         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 3191        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014874571 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 1.31e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 344         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | -91.4        |
# | time/                   |              |
# |    fps                  | 3172         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0056264624 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | -0.00147     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 214          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00523     |
# |    value_loss           | 277          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | -84.7        |
# | time/                   |              |
# |    fps                  | 3162         |
# |    iterations           | 11           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0030916904 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.000583     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 225          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | -85.9        |
# | time/                   |              |
# |    fps                  | 3155         |
# |    iterations           | 12           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0072804475 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0165       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.007       |
# |    value_loss           | 112          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -85.2       |
# | time/                   |             |
# |    fps                  | 3153        |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008258164 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.068       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 327         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 545         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | -83.9       |
# | time/                   |             |
# |    fps                  | 3149        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005992764 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 244         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | -78.3       |
# | time/                   |             |
# |    fps                  | 3143        |
# |    iterations           | 15          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005143569 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.0506     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 172         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 264         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | -79          |
# | time/                   |              |
# |    fps                  | 3141         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0032112342 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64.9         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 194          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | -75.6        |
# | time/                   |              |
# |    fps                  | 3131         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0055918247 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.377        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.2         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 194          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -71.7        |
# | time/                   |              |
# |    fps                  | 3126         |
# |    iterations           | 18           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0112932045 |
# |    clip_fraction        | 0.098        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.6         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0114      |
# |    value_loss           | 120          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | -68         |
# | time/                   |             |
# |    fps                  | 3121        |
# |    iterations           | 19          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007357169 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 174         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 221         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 263          |
# |    ep_rew_mean          | -67.3        |
# | time/                   |              |
# |    fps                  | 3122         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0064301873 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.6         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 137          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 272          |
# |    ep_rew_mean          | -62.2        |
# | time/                   |              |
# |    fps                  | 3119         |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0048180297 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.355        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.5         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00508     |
# |    value_loss           | 324          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | -60.8       |
# | time/                   |             |
# |    fps                  | 3119        |
# |    iterations           | 22          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013272702 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 152         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 303          |
# |    ep_rew_mean          | -57.8        |
# | time/                   |              |
# |    fps                  | 3114         |
# |    iterations           | 23           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0056831487 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.727        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72           |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00692     |
# |    value_loss           | 138          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | -56.7       |
# | time/                   |             |
# |    fps                  | 3109        |
# |    iterations           | 24          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010115289 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 65.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | -54          |
# | time/                   |              |
# |    fps                  | 3105         |
# |    iterations           | 25           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0084357485 |
# |    clip_fraction        | 0.0879       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.82         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00625     |
# |    value_loss           | 49.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | -50.5       |
# | time/                   |             |
# |    fps                  | 3104        |
# |    iterations           | 26          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011067018 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 41.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 363         |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 3106        |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.016684009 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 35.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | -55          |
# | time/                   |              |
# |    fps                  | 3106         |
# |    iterations           | 28           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0073860222 |
# |    clip_fraction        | 0.0759       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.295        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.3         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00765     |
# |    value_loss           | 192          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 395         |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 3100        |
# |    iterations           | 29          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011237524 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 92.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 401         |
# |    ep_rew_mean          | -54.8       |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 30          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020048335 |
# |    clip_fraction        | 0.0706      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 163         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | -53.5       |
# | time/                   |             |
# |    fps                  | 3100        |
# |    iterations           | 31          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008411858 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.9        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 157         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 421          |
# |    ep_rew_mean          | -46.5        |
# | time/                   |              |
# |    fps                  | 3101         |
# |    iterations           | 32           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0053696893 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | 0.429        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.5         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 118          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 440        |
# |    ep_rew_mean          | -40.2      |
# | time/                   |            |
# |    fps                  | 3102       |
# |    iterations           | 33         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00932084 |
# |    clip_fraction        | 0.0573     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.821     |
# |    explained_variance   | 0.162      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 171        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00607   |
# |    value_loss           | 142        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 456         |
# |    ep_rew_mean          | -33.5       |
# | time/                   |             |
# |    fps                  | 3103        |
# |    iterations           | 34          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011045383 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00686    |
# |    value_loss           | 97.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 467         |
# |    ep_rew_mean          | -22.1       |
# | time/                   |             |
# |    fps                  | 3102        |
# |    iterations           | 35          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007380881 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 481         |
# |    ep_rew_mean          | -9.2        |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 36          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006068166 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.853      |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63          |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 481         |
# |    ep_rew_mean          | -4.52       |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 37          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006298567 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 112         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | 9.1          |
# | time/                   |              |
# |    fps                  | 3102         |
# |    iterations           | 38           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0041098967 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 507          |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 3100         |
# |    iterations           | 39           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0073706405 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.2         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 514         |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 3096        |
# |    iterations           | 40          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011767769 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.8        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 60.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 525          |
# |    ep_rew_mean          | 28.4         |
# | time/                   |              |
# |    fps                  | 3096         |
# |    iterations           | 41           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0037861923 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.8         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 70.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 545          |
# |    ep_rew_mean          | 33.6         |
# | time/                   |              |
# |    fps                  | 3097         |
# |    iterations           | 42           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0047556283 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.806       |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.9         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 50.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 556          |
# |    ep_rew_mean          | 39.1         |
# | time/                   |              |
# |    fps                  | 3098         |
# |    iterations           | 43           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0045454944 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.1         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 137          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 556         |
# |    ep_rew_mean          | 47.8        |
# | time/                   |             |
# |    fps                  | 3099        |
# |    iterations           | 44          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004494562 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.951      |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 143         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 122         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 564        |
# |    ep_rew_mean          | 52.8       |
# | time/                   |            |
# |    fps                  | 3100       |
# |    iterations           | 45         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01572975 |
# |    clip_fraction        | 0.0485     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.778     |
# |    explained_variance   | 0.767      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.3       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00285   |
# |    value_loss           | 63.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 565         |
# |    ep_rew_mean          | 58.8        |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 46          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002065606 |
# |    clip_fraction        | 0.00376     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.6        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 253         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 566          |
# |    ep_rew_mean          | 65.5         |
# | time/                   |              |
# |    fps                  | 3101         |
# |    iterations           | 47           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0056164106 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 0.378        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 225          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 188          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 580         |
# |    ep_rew_mean          | 71.5        |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 48          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004080586 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.7        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 211         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 591         |
# |    ep_rew_mean          | 81          |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 49          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.012691945 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 42.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 607         |
# |    ep_rew_mean          | 86.1        |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 50          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010076783 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.2        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 43          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 617         |
# |    ep_rew_mean          | 92.2        |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 51          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007353394 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.1        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 108         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 633          |
# |    ep_rew_mean          | 94.1         |
# | time/                   |              |
# |    fps                  | 3101         |
# |    iterations           | 52           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0036652016 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.6         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 52.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 644          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 3100         |
# |    iterations           | 53           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0042108684 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.8         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00339     |
# |    value_loss           | 99.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 646         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 54          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004268253 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 49.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 649         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 3100        |
# |    iterations           | 55          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 112640      |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 560          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 3076         |
# |    iterations           | 81           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0069592684 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.82        |
# |    explained_variance   | 0.515        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.4         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00508     |
# |    value_loss           | 114          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 3075        |
# |    iterations           | 82          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.008989541 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.68        |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 555         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 3075        |
# |    iterations           | 83          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.003269276 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 2.93e-05    |
# |    value_loss           | 88.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 555          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 3074         |
# |    iterations           | 84           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0046492154 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.779       |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.5         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 84.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 547          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 3074         |
# |    iterations           | 85           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0041412446 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.4         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 126          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 540          |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 3074         |
# |    iterations           | 86           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0071860114 |
# |    clip_fraction        | 0.0764       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 40.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 526          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 3073         |
# |    iterations           | 87           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0077183116 |
# |    clip_fraction        | 0.0898       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.21         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 522          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 3073         |
# |    iterations           | 88           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0082388865 |
# |    clip_fraction        | 0.0938       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00724     |
# |    value_loss           | 44.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 522        |
# |    ep_rew_mean          | 160        |
# | time/                   |            |
# |    fps                  | 3071       |
# |    iterations           | 89         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.00332412 |
# |    clip_fraction        | 0.0392     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.817     |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 156        |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.00289   |
# |    value_loss           | 109        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 3069        |
# |    iterations           | 90          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.005209263 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.45        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.000532   |
# |    value_loss           | 19.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 519          |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 3068         |
# |    iterations           | 91           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0138504775 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.13         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 27           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 514          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 3068         |
# |    iterations           | 92           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0027975938 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.534        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 152          |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 229          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 518         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 3067        |
# |    iterations           | 93          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.006471334 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00423    |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 519         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 3064        |
# |    iterations           | 94          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.007565125 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 519         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 3061        |
# |    iterations           | 95          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.020511232 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.2        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 71.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 521         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 3059        |
# |    iterations           | 96          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.011512256 |
# |    clip_fraction        | 0.0694      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.8        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00218    |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 517         |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 3058        |
# |    iterations           | 97          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.012033125 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 73.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 505         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 3058        |
# |    iterations           | 98          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.003744806 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.8        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00214    |
# |    value_loss           | 150         |
# -----------------------------------------

# %%
# SOLUTION
# We added some parameters to accelerate the training
model = PPO(
    policy="MlpPolicy",
    env=env,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1,
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# SOLUTION
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=100000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    fps             | 4762     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -175         |
# | time/                   |              |
# |    fps                  | 4541         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0005621424 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0538      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.83e+03     |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 4.78e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.7        |
# |    ep_rew_mean          | -148        |
# | time/                   |             |
# |    fps                  | 4475        |
# |    iterations           | 3           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.001766351 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000941   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.07e+03    |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 4.49e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97           |
# |    ep_rew_mean          | -144         |
# | time/                   |              |
# |    fps                  | 4433         |
# |    iterations           | 4            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0018551464 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00304     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 564          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 1.46e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.8         |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 4390         |
# |    iterations           | 5            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0038651049 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000595    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05e+03     |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 2.23e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.7         |
# |    ep_rew_mean          | -144         |
# | time/                   |              |
# |    fps                  | 4351         |
# |    iterations           | 6            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0013498454 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0086      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 2.37e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.6         |
# |    ep_rew_mean          | -150         |
# | time/                   |              |
# |    fps                  | 4346         |
# |    iterations           | 7            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0076760026 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00236     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00971     |
# |    value_loss           | 2.66e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 101           |
# |    ep_rew_mean          | -150          |
# | time/                   |               |
# |    fps                  | 4277          |
# |    iterations           | 8             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00096246484 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.00172      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.79e+03      |
# |    n_updates            | 68            |
# |    policy_gradient_loss | -0.00205      |
# |    value_loss           | 4.85e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 102           |
# |    ep_rew_mean          | -146          |
# | time/                   |               |
# |    fps                  | 4284          |
# |    iterations           | 9             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00074305775 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.006        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.46e+03      |
# |    n_updates            | 72            |
# |    policy_gradient_loss | -0.00237      |
# |    value_loss           | 2.88e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 4286        |
# |    iterations           | 10          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009199237 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00566    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 485         |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 965         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 4296        |
# |    iterations           | 11          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.008393921 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.005      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 663         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00746    |
# |    value_loss           | 1.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 4292        |
# |    iterations           | 12          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013401469 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000396   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 312         |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 739         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -132         |
# | time/                   |              |
# |    fps                  | 4294         |
# |    iterations           | 13           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0015883439 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 5.38e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 822          |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 1.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | -137         |
# | time/                   |              |
# |    fps                  | 4299         |
# |    iterations           | 14           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0006850916 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -9.43e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000838    |
# |    value_loss           | 2.14e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 4303        |
# |    iterations           | 15          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.006143269 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.000278   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 542         |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00468    |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | -140         |
# | time/                   |              |
# |    fps                  | 4307         |
# |    iterations           | 16           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0022961427 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.0144      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 807          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 1.41e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 4301        |
# |    iterations           | 17          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.002154644 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.00171    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06e+03    |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 3.62e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 4296        |
# |    iterations           | 18          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008972314 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0411      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 227         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 4299         |
# |    iterations           | 19           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0005252816 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.00565      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.000223    |
# |    value_loss           | 2.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | -133         |
# | time/                   |              |
# |    fps                  | 4302         |
# |    iterations           | 20           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0009829046 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.00156     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+03     |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 2.79e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | -129        |
# | time/                   |             |
# |    fps                  | 4304        |
# |    iterations           | 21          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008881259 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.00168    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 327         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 695         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | -126         |
# | time/                   |              |
# |    fps                  | 4307         |
# |    iterations           | 22           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0080973795 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -0.000892    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 496          |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 775          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 4310         |
# |    iterations           | 23           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0007493397 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.00471     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 547          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000527    |
# |    value_loss           | 1.25e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 4306        |
# |    iterations           | 24          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006222563 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.00362    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 192         |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 576         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 150           |
# |    ep_rew_mean          | -119          |
# | time/                   |               |
# |    fps                  | 4306          |
# |    iterations           | 25            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 0.00060150237 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | 0.0436        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 111           |
# |    n_updates            | 136           |
# |    policy_gradient_loss | -0.000927     |
# |    value_loss           | 376           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 4309         |
# |    iterations           | 26           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0113061145 |
# |    clip_fraction        | 0.0796       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0198       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 223          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 350          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 4307         |
# |    iterations           | 27           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0058373036 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -0.0304      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 164          |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 525          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 4308         |
# |    iterations           | 28           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0051839305 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.0426       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 297          |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.0072      |
# |    value_loss           | 652          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 4307         |
# |    iterations           | 29           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0019171266 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 337          |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 778          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 4306        |
# |    iterations           | 30          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005657145 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 596         |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 4303        |
# |    iterations           | 31          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.002923728 |
# |    clip_fraction        | 0.00708     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 284         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 487         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | -92.7        |
# | time/                   |              |
# |    fps                  | 4294         |
# |    iterations           | 32           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0024383736 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 131          |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.0082      |
# |    value_loss           | 316          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 189           |
# |    ep_rew_mean          | -90.8         |
# | time/                   |               |
# |    fps                  | 4287          |
# |    iterations           | 33            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 0.00013811846 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.14         |
# |    explained_variance   | -0.00636      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 281           |
# |    n_updates            | 168           |
# |    policy_gradient_loss | -7.14e-05     |
# |    value_loss           | 607           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -86.2        |
# | time/                   |              |
# |    fps                  | 4281         |
# |    iterations           | 34           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0057977173 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.9         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -85.7        |
# | time/                   |              |
# |    fps                  | 4278         |
# |    iterations           | 35           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0072059957 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.00827     |
# |    value_loss           | 170          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | -76.1        |
# | time/                   |              |
# |    fps                  | 4274         |
# |    iterations           | 36           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0006824957 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 248          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 211           |
# |    ep_rew_mean          | -72.9         |
# | time/                   |               |
# |    fps                  | 4274          |
# |    iterations           | 37            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 37888         |
# | train/                  |               |
# |    approx_kl            | 0.00018044189 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.16         |
# |    explained_variance   | -0.0912       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 228           |
# |    n_updates            | 184           |
# |    policy_gradient_loss | -0.000503     |
# |    value_loss           | 703           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 218           |
# |    ep_rew_mean          | -73.9         |
# | time/                   |               |
# |    fps                  | 4269          |
# |    iterations           | 38            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00050859957 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.18         |
# |    explained_variance   | 0.241         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 168           |
# |    n_updates            | 188           |
# |    policy_gradient_loss | -0.000828     |
# |    value_loss           | 408           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 218           |
# |    ep_rew_mean          | -74.2         |
# | time/                   |               |
# |    fps                  | 4268          |
# |    iterations           | 39            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 39936         |
# | train/                  |               |
# |    approx_kl            | 0.00015660143 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | 0.354         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 162           |
# |    n_updates            | 192           |
# |    policy_gradient_loss | -0.000159     |
# |    value_loss           | 430           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | -66.8        |
# | time/                   |              |
# |    fps                  | 4268         |
# |    iterations           | 40           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0027202715 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.8         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | -62.8        |
# | time/                   |              |
# |    fps                  | 4268         |
# |    iterations           | 41           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0038722758 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.391        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 301          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 239          |
# |    ep_rew_mean          | -60.9        |
# | time/                   |              |
# |    fps                  | 4263         |
# |    iterations           | 42           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0001397995 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 299          |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000274    |
# |    value_loss           | 705          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 240          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 4263         |
# |    iterations           | 43           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0002521777 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 100          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000684    |
# |    value_loss           | 812          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 244          |
# |    ep_rew_mean          | -46.5        |
# | time/                   |              |
# |    fps                  | 4260         |
# |    iterations           | 44           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0020456605 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.459        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 300          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | -45.2       |
# | time/                   |             |
# |    fps                  | 4258        |
# |    iterations           | 45          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.000871216 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 226         |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 447         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 254         |
# |    ep_rew_mean          | -43.5       |
# | time/                   |             |
# |    fps                  | 4251        |
# |    iterations           | 46          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004996525 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 255         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 263         |
# |    ep_rew_mean          | -40.3       |
# | time/                   |             |
# |    fps                  | 4247        |
# |    iterations           | 47          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.005659803 |
# |    clip_fraction        | 0.0171      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 134         |
# |    n_updates            | 224         |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 188         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 273          |
# |    ep_rew_mean          | -37.5        |
# | time/                   |              |
# |    fps                  | 4247         |
# |    iterations           | 48           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0005860804 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.637        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 375          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | -36.5       |
# | time/                   |             |
# |    fps                  | 4244        |
# |    iterations           | 49          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.006284796 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.8        |
# |    n_updates            | 232         |
# |    policy_gradient_loss | -0.00517    |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | -29.5        |
# | time/                   |              |
# |    fps                  | 4243         |
# |    iterations           | 50           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0025417963 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.8         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 209          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | -28.9       |
# | time/                   |             |
# |    fps                  | 4242        |
# |    iterations           | 51          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.011541713 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.7        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 178         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -28         |
# | time/                   |             |
# |    fps                  | 4243        |
# |    iterations           | 52          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005078482 |
# |    clip_fraction        | 0.0144      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.6        |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 182         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 303           |
# |    ep_rew_mean          | -27.4         |
# | time/                   |               |
# |    fps                  | 4244          |
# |    iterations           | 53            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 54272         |
# | train/                  |               |
# |    approx_kl            | 0.00055229466 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.18         |
# |    explained_variance   | 0.767         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 184           |
# |    n_updates            | 248           |
# |    policy_gradient_loss | -0.0013       |
# |    value_loss           | 357           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | -27.4        |
# | time/                   |              |
# |    fps                  | 4241         |
# |    iterations           | 54           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0012830263 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 138          |
# |    n_updates            | 252          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 204          |
# ...
# |    value_loss           | 419           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 4124         |
# |    iterations           | 450          |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 460800       |
# | train/                  |              |
# |    approx_kl            | 0.0007089118 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.17         |
# |    n_updates            | 1836         |
# |    policy_gradient_loss | -0.000755    |
# |    value_loss           | 89           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 714         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 4124        |
# |    iterations           | 451         |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 461824      |
# | train/                  |             |
# |    approx_kl            | 0.018103912 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.766      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 8.48        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 714           |
# |    ep_rew_mean          | 106           |
# | time/                   |               |
# |    fps                  | 4124          |
# |    iterations           | 452           |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 462848        |
# | train/                  |               |
# |    approx_kl            | 0.00081722194 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.905        |
# |    explained_variance   | 0.78          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 52            |
# |    n_updates            | 1844          |
# |    policy_gradient_loss | -0.00213      |
# |    value_loss           | 394           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 709         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 4124        |
# |    iterations           | 453         |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 463872      |
# | train/                  |             |
# |    approx_kl            | 0.008118064 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.911       |
# |    n_updates            | 1848        |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 8.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 709         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 4123        |
# |    iterations           | 454         |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 464896      |
# | train/                  |             |
# |    approx_kl            | 0.006476443 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.9        |
# |    n_updates            | 1852        |
# |    policy_gradient_loss | 0.000624    |
# |    value_loss           | 260         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 707         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 4123        |
# |    iterations           | 455         |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 465920      |
# | train/                  |             |
# |    approx_kl            | 0.012586268 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 1856        |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 5.07        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 713          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 4123         |
# |    iterations           | 456          |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 0.0007879019 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.947       |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.5         |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -2.53e-05    |
# |    value_loss           | 149          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 706         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 4123        |
# |    iterations           | 457         |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 467968      |
# | train/                  |             |
# |    approx_kl            | 0.009969011 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.979       |
# |    n_updates            | 1864        |
# |    policy_gradient_loss | -0.000239   |
# |    value_loss           | 3.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 698          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 4123         |
# |    iterations           | 458          |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 0.0035751318 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 240          |
# |    n_updates            | 1868         |
# |    policy_gradient_loss | -1.07e-05    |
# |    value_loss           | 355          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 698          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 4123         |
# |    iterations           | 459          |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 470016       |
# | train/                  |              |
# |    approx_kl            | 0.0001490232 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 140          |
# |    n_updates            | 1872         |
# |    policy_gradient_loss | -0.000661    |
# |    value_loss           | 330          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 683          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 4123         |
# |    iterations           | 460          |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 0.0011237811 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.51         |
# |    n_updates            | 1876         |
# |    policy_gradient_loss | -0.000154    |
# |    value_loss           | 17           |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 683           |
# |    ep_rew_mean          | 101           |
# | time/                   |               |
# |    fps                  | 4122          |
# |    iterations           | 461           |
# |    time_elapsed         | 114           |
# |    total_timesteps      | 472064        |
# | train/                  |               |
# |    approx_kl            | 0.00019663316 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.823        |
# |    explained_variance   | 0.713         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 320           |
# |    n_updates            | 1880          |
# |    policy_gradient_loss | -0.000451     |
# |    value_loss           | 666           |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 # SOLUTION
#       2 # Train it for 1,000,000 timesteps
# ----> 3 model.learn(total_timesteps=100000000)
#       4 # Save the model
#       5 model_name = "ppo-LunarLander-v2"
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:300, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 assert self.env is not None
#     299 while self.num_timesteps < total_timesteps:
# --> 300     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     302     if not continue_training:
#     303         break
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:195, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     190     else:
#     191         # Otherwise, clip the actions to avoid out of bound error
#     192         # as we are sampling from an unbounded Gaussian distribution
#     193         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 195 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     197 self.num_timesteps += env.num_envs
#     199 # Give access to local variables
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/envs/box2d/lunar_lander.py:631, in LunarLander.step(self, action)
#     617         p.ApplyLinearImpulse(
#     618             (
#     619                 ox * SIDE_ENGINE_POWER * s_power,
#    (...)
#     623             True,
#     624         )
#     625     self.lander.ApplyLinearImpulse(
#     626         (-ox * SIDE_ENGINE_POWER * s_power, -oy * SIDE_ENGINE_POWER * s_power),
#     627         impulse_pos,
#     628         True,
#     629     )
# --> 631 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     633 pos = self.lander.position
#     634 vel = self.lander.linearVelocity
#
# KeyboardInterrupt:
